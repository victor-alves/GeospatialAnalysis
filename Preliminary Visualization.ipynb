# %%
import pandas as pd
import numpy as np
import warnings
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import rcParams

# %% [markdown]
# This is needed to ensure that axis labels are not cut off when exporting the graphs.

# %%
rcParams.update({"figure.autolayout": True})

# %%
sns.set(style="white", color_codes=True)

# %%
df = pd.read_csv("clean_data.csv")
df.head(1)
# Out:
#    Unnamed: 0                                    id  adults   age  antiques  \
# 0           0  0d422ed1-239f-4c23-913c-9ed013016274     1.0  48.0     False
#
#   architecture_type  avid_collector  bank_card_in_household  baths  beds  \
# 0             RANCH           False                   False    3.0   5.0
#
#     ...     tax_year  tech_focused  travel  trust  units  womens_apparel  \
# 0   ...       2016.0          True   False  False    1.0           False
#
#    year_built  private_san_leandro_high_energy_use  \
# 0      1952.0                                False
#
#   private_stop_waste_clearesult    label
# 0                         False  awesome
#
# [1 rows x 95 columns]

# %%
f, (ax1, ax2, ax3, ax4) = plt.subplots(4)
# Out:
# /usr/lib64/python3.6/site-packages/matplotlib/figure.py:1742: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
archs = df["architecture_type"].value_counts().values.tolist()
names = df["architecture_type"].value_counts().index.tolist()
indexes = np.asarray(list(range(len(archs))))

df2 = pd.DataFrame({"architecture_type": archs, "names": names})
df2.set_index(indexes, inplace=True)

z = sns.barplot(y="architecture_type", x="names", ci="sd", errwidth=.8, data=df2)
z.set_xticklabels(labels=names, rotation=90)
# Out:
# ...
# /usr/lib64/python3.6/site-packages/matplotlib/figure.py:1742: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
ax2 = df['tax_year'].value_counts().plot.bar()
# Out:
# /usr/lib64/python3.6/site-packages/matplotlib/figure.py:1742: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
ax3 = df['garage_spaces'].value_counts().plot.bar()
# Out:
# /usr/lib64/python3.6/site-packages/matplotlib/figure.py:1742: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
ax4 = df['primary_language'].value_counts().plot.bar()
# Out:
# /usr/lib64/python3.6/site-packages/matplotlib/figure.py:1742: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
df["marital_status"].value_counts().plot.bar()
# Out:
# /usr/lib64/python3.6/site-packages/matplotlib/figure.py:1742: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
df['political_donor'].value_counts().plot.bar()
# Out:
# /usr/lib64/python3.6/site-packages/matplotlib/figure.py:1742: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
sns.distplot(df["net_worth"], kde=False)
# Out:
# /usr/lib64/python3.6/site-packages/matplotlib/figure.py:1742: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
sns.FacetGrid(df, col="education")\
    .map(plt.hist, "net_worth", bins=10)
# Out:
# /usr/lib64/python3.6/site-packages/matplotlib/figure.py:1742: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
df2 = df.pivot_table(index='education', 
                   columns='generations', 
                   values='net_worth', 
                   aggfunc='mean')
#df2 = df.pivot(index="education", columns="construction_type", values="net_worth")
sns.heatmap(df2)
# Out:
# /usr/lib64/python3.6/site-packages/matplotlib/figure.py:1742: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
g = sns.barplot(x="occupation", y="net_worth", hue="gender", ci=False, data=df)
g.set_xticklabels(labels=df["occupation"].value_counts().index.tolist(), rotation=90)
# Out:
# /usr/lib64/python3.6/site-packages/matplotlib/figure.py:1742: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
z = sns.barplot(x="occupation", y="credit_rating", hue="gender", data=df)
z.set_xticklabels(labels=df["occupation"].value_counts().index.tolist(), rotation=90)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
# Out:
# /usr/lib64/python3.6/site-packages/matplotlib/figure.py:1742: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
df['tax_year'].value_counts().plot.bar()

# %%
lf = sns.barplot(x="primary_language", y="net_worth", data=df)
lf.set_xticklabels(labels=df["primary_language"].value_counts().index.tolist(), rotation=270)
lf.set(xlabel = "Primary Language", ylabel = "Net Worth")
# Out:
# ...
# /usr/lib64/python3.6/site-packages/matplotlib/figure.py:1742: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "
